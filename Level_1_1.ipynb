# %%
import pandas as pd

# %%
df =pd.read_csv("Dataset.csv")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
df.tail(2)
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude         Cuisines  ...  \
# 9549  Kuru�_e��me, ��stanbul  29.036019  41.057979  Restaurant Cafe  ...
# 9550         Moda, ��stanbul  29.026016  40.984776             Cafe  ...
#
#               Currency Has Table booking Has Online delivery  \
# 9549  Turkish Lira(TL)                No                  No
# 9550  Turkish Lira(TL)                No                  No
#
#      Is delivering now Switch to order menu Price range  Aggregate rating  \
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.fillna("none",inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
sort_a = df.sort_values(by="Restaurant Name")
sort_a
# Out:
#       Restaurant ID       Restaurant Name  Country Code             City  \
# 2459        3100446                   #45             1        Mangalore
# 9148       18378803          #Dilliwaala6             1       Puducherry
# 2613       18311951          #InstaFreeze             1        New Delhi
# 6998       18336489           #OFF Campus             1        New Delhi
# 8692       18317511          #Urban Caf��             1            Noida
# ...             ...                   ...           ...              ...
# 4659       18361747    t Lounge by Dilmah             1        New Delhi
# 9454        6401789                tashas           189        Cape Town
# 9334        7100938              wagamama           148  Wellington City
# 3120       18222559  {Niche} - Cafe & Bar             1        New Delhi
# 9523        6000871     �ukura��a Sofras۱           208           Ankara
#
#                                                 Address            Locality  \
# ...

# %%
sort_d = df.sort_values("Cuisines",ascending=False)
sort_d.tail(9)
# Out:
#       Restaurant ID        Restaurant Name  Country Code       City  \
# 616         5600701                Nando s           214    Sharjah
# 9465          75027                  Kream           189   Pretoria
# 7302         301675                   Lush             1  New Delhi
# 1910       18435789              Al Fanoos             1    Gurgaon
# 3491       18355119             Al  Sheikh             1  New Delhi
# 4866         302577            Kabul Delhi             1  New Delhi
# 4268       18481273  Pak Afghan Restaurant             1  New Delhi
# 1914       18458635           Burj Al Arab             1    Gurgaon
# 1909       18352250          Afghan Indian             1    Gurgaon
#
#                                                 Address           Locality  \
# 616   Ground level, Block D, Qanat Al Qasba, Al Khan...  Al Qasba, Al Khan
# 9465             570 Fehrsen Street, Brooklyn, Pretoria           Brooklyn
# ...

# %%
df['Restaurant Name'] = df['Restaurant Name'].str.replace('[^a-zA-z\s]',' ',regex=True).str.strip()
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat   Edsa Shangri La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml  Gurme           208         ��stanbul
# 9547        5908749               Ceviz A  ac           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A   k Kahve           208         ��stanbul
# 9550        5927402  Walter s Coffee Roastery           208         ��stanbul
#
# ...

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat   Edsa Shangri La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml  Gurme           208         ��stanbul
# 9547        5908749               Ceviz A  ac           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A   k Kahve           208         ��stanbul
# 9550        5927402  Walter s Coffee Roastery           208         ��stanbul
#
# ...

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat   Edsa Shangri La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml  Gurme           208         ��stanbul
# 9547        5908749               Ceviz A  ac           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A   k Kahve           208         ��stanbul
# 9550        5927402  Walter s Coffee Roastery           208         ��stanbul
#
# ...

# %%
sc = df.sort_values('Cuisines');
sc.head(3)['Cuisines']
# Out:
# 4268    Afghani
# 4866    Afghani
# 1914    Afghani
# Name: Cuisines, dtype: object

# %%
df.dropna(inplace=True)
pd.isnull(df).count()
# Out:
# Restaurant ID           9551
# Restaurant Name         9551
# Country Code            9551
# City                    9551
# Address                 9551
# Locality                9551
# Locality Verbose        9551
# Longitude               9551
# Latitude                9551
# Cuisines                9551
# Average Cost for two    9551
# Currency                9551
# Has Table booking       9551
# Has Online delivery     9551
# Is delivering now       9551
# Switch to order menu    9551
# Price range             9551
# Aggregate rating        9551
# Rating color            9551
# Rating text             9551
# Votes                   9551
# dtype: int64

# %%
df['Cuisines']
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %% [markdown]
# Level 1
# Task -1

# %%
cu_count = df['Cuisines'].value_counts()
cu_count
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1826, dtype: int64

# %%
c_count = df['Cuisines'].str.split(', ').explode('Cuisines').value_counts()
c_count
# Out:
# Cuisines
# North Indian      3960
# Chinese           2735
# Fast Food         1986
# Mughlai            995
# Italian            764
#                   ...
# Fish and Chips       1
# Malwani              1
# Cuisine Varies       1
# Soul Food            1
# B�_rek               1
# Name: count, Length: 145, dtype: int64

# %%
top_3 = c_count.head(3)
top_3
# Out:
# Cuisines
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

colours = ['green','orange','red']
plt.bar(top_3.index,top_3.values,color=colours)
plt.xlabel('cuisine')
plt.ylabel("Count")
plt.title("top 3 data in cuisines")
plt.show()

# %% [markdown]
# Calculate
# the
# percentage
# of
#  restaurants that serve each of the top
#  cuisines.

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
total_r = len(df)
total_r
top_c = c_count.head()
percentage = (top_c/total_r)*100
print("the top 5 ",percentage)
# Out:
# the top 5  Cuisines
# North Indian    41.461627
# Chinese         28.635745
# Fast Food       20.793634
# Mughlai         10.417757
# Italian          7.999162
# Name: count, dtype: float64

# %%
total = len(df)
top = c_count.head(10)
pe = (top/total)*100
pe
# Out:
# Cuisines
# North Indian    41.461627
# Chinese         28.635745
# Fast Food       20.793634
# Mughlai         10.417757
# Italian          7.999162
# Bakery           7.800230
# Continental      7.705999
# Cafe             7.360486
# Desserts         6.836980
# South Indian     6.658989
# Name: count, dtype: float64

# %%
plt.bar(top_c.index,percentage.values,color = colours)
plt.xlabel("name ")
plt.ylabel("top pecntage ")
plt.title("top percentage ....")
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
#  Task 2
# **bold text**
